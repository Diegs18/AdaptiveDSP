# %%
import matplotlib.pyplot as plt
def freq_resp(b = [1], a = [1, -.9]):
    
    # Calculate the frequency response
    w, h = sig.freqz(b, a)

    # Plot the magnitude and phase response
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 1)
    plt.plot(w/np.pi, 20 * np.log10(abs(h)))
    plt.xlabel('Normalized Frequency (rad/sample)')
    plt.ylabel('Magnitude (dB)')
    plt.title('Magnitude Response')

    plt.subplot(2, 1, 2)
    plt.plot(w, np.angle(h, deg=True))
    plt.xlabel('Normalized Frequency (rad/sample)')
    plt.ylabel('Phase (degrees)')
    plt.title('Phase Response')

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
def LMS(d, x, L, mu, N):
    y = np.zeros_like(d)
    e = np.zeros_like(d)
    bhat = np.zeros([1, L+1])
    for n in range(L,N):
        xv = np.flip(x[n-L:n+1])
        y = np.dot(bhat, xv)
        e[n] = d[n]-y
        bhat = bhat + 2*mu*e[n]*xv

    freq_resp(bhat.reshape(L+1,1), [1])
    plt.plot(10*np.log10(e*e+.0000001))
    plt.ylabel('MSE (dB)')
    plt.xlabel('Iteration')
    string = 'Mu = ' + str(mu)
    plt.title(string)
    plt.show()
    return bhat

# %%
import numpy as np
def LMS2(d, x, L, mu, N):
    y = np.zeros_like(d)
    e = np.zeros_like(d)
    bhat = np.zeros([1, L+1])
    for n in range(L,N):
        xv = np.flip(x[n-L:n+1])
        y = np.dot(bhat, xv)
        e[n] = d[n]-y
        bhat = bhat + 2*mu*e[n]*xv
    return e

# %% [markdown]
# # Problem 2

# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt

b = [1]
a = [1, .85]
N  = 500 #number of iterations 
mu = .05
x = np.random.normal(0, 1, N)
d = sig.lfilter(b, a, x)
freq_resp(b, a)

# %% [markdown]
# ## Probolem 2a for L=2

# %%
#probolem 2a for L=2
mu = .05
L  =  2 #filter order, number of coefficients - 1
bhat = LMS(d, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 2
# Coefficients are: [[ 1.09392744 -0.83752848  0.54958184]]

# %% [markdown]
# ## Probolem 2a for L = 4

# %%
#probolem 2a for L=4
mu = .05
L  =  4 #filter order, number of coefficients - 1
bhat = LMS(d, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 4
# Coefficients are: [[ 0.90088348 -0.80886227  0.81528462 -0.64711252  0.37767688]]

# %% [markdown]
# ## Probolem 2a for L = 16

# %%
#probolem 2a for L=16, also best mu
mu = .03
L  =  16 #filter order, number of coefficients - 1
bhat = LMS(d, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 16
# Coefficients are: [[ 0.98861891 -0.83508966  0.69400836 -0.56396038  0.45628221 -0.37433145
#    0.31419778 -0.28263653  0.22442935 -0.18236852  0.14661525 -0.15349259
#    0.13212219 -0.11132273  0.12269434 -0.07804393  0.08211217]]

# %% [markdown]
# ## Problem 2c L = 16, small Mu

# %%
#probolem 2a for L=16
mu = .003
L  =  16 #filter order, number of coefficients - 1
bhat = LMS(d, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 16
# Coefficients are: [[ 0.92470047 -0.78924538  0.65846881 -0.55445074  0.47073967 -0.38886783
#    0.32654599 -0.28047483  0.22957585 -0.19893656  0.15974196 -0.11912775
#    0.10616519 -0.07908094  0.06349646 -0.05126447  0.03762297]]

# %% [markdown]
# # Problem 3

# %%
N  = 500 #number of iterations 

#run the signal through F(z)
b = [1, -1, 1]
a = [1]
color_d = sig.lfilter(b, a, x)


#run the signal through H(z)
b = [1]
a = [1, .85]
d2 = sig.lfilter(b, a, color_d)
freq_resp(b, a)

# %% [markdown]
# ## Problem 3a L=2

# %%
#probolem 2a for L=2, also best mu
mu = .05
L  =  2 #filter order, number of coefficients - 1
bhat = LMS(d2, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 2
# Coefficients are: [[ 1.33443368 -1.80559449  1.95681563]]

# %% [markdown]
# ## Problem 3a L=4

# %%
#probolem 2a for L=4, also best mu
mu = .005
L  =  4 #filter order, number of coefficients - 1
bhat = LMS(d2, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 4
# Coefficients are: [[ 0.64159661 -1.56899125  2.46356263 -2.04032789  1.87826164]]

# %%
#probolem 2a for L=16, also best mu
mu = .005
L  =  16 #filter order, number of coefficients - 1
bhat = LMS(d2, x, L, mu, N)
print('For Filter order', L, '\nCoefficients are:',bhat)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\1358236718.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y
# For Filter order 16
# Coefficients are: [[ 0.95223169 -1.79464326  2.50531727 -2.11196394  1.76874679 -1.49432284
#    1.25360686 -1.07409202  0.89271826 -0.7467105   0.63469947 -0.533422
#    0.44220566 -0.38228907  0.33355947 -0.26019459  0.24259024]]

# %% [markdown]
# ## Problem 3c L=16 double plot with white/colored noise

# %%
#probolem 3c for L=16, also best mu
mu = .03
L  =  16 #filter order, number of coefficients - 1

e_d = LMS2(d, x, L, mu, N)
e_colord = LMS2(d2, x, L, mu, N)


plt.plot(10*np.log10(e_d*e_d+.0000001), label='white')
plt.plot(10*np.log10(e_colord*e_colord+.0000001), label='Colored')
plt.legend()
plt.ylabel('MSE (dB)')
plt.xlabel('Iteration')
plt.title('Best Mu = 0.03')
plt.show()
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\3535272067.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y

# %%
#probolem 3c for L=16, also best mu
mu = .003
L  =  16 #filter order, number of coefficients - 1

e_d = LMS2(d, x, L, mu, N)
e_colord = LMS2(d2, x, L, mu, N)


plt.plot(10*np.log10(e_d*e_d+.0000001), label='white')
plt.plot(10*np.log10(e_colord*e_colord+.0000001), label='Colored')
plt.legend()
plt.ylabel('MSE (dB)')
plt.xlabel('Iteration')
plt.title('Small Mu = 0.003')
plt.show()
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_32784\3535272067.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   e[n] = d[n]-y

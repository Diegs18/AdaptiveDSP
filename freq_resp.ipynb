# %%
import numpy as np
from scipy.signal import freqz
import matplotlib.pyplot as plt
import scipy.fft as fft
import scipy.signal as sig

# %%
def filter_b_a_freq_resp(b = [1], a = [1, -.9]):

    # Calculate the frequency response
    w, h = freqz(b, a)

    # Plot the magnitude and phase response
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 1)
    plt.plot(w, 20 * np.log10(abs(h)))
    plt.xlabel('Normalized Frequency (rad/sample)')
    plt.ylabel('Magnitude (dB)')
    plt.title('Magnitude Response')

    plt.subplot(2, 1, 2)
    plt.plot(w, np.angle(h, deg=True))
    plt.xlabel('Normalized Frequency (rad/sample)')
    plt.ylabel('Phase (degrees)')
    plt.title('Phase Response')

    plt.tight_layout()
    plt.show()

# %%
g = 0.1
a1 =(g-1)/(1+g)
b0 = 1+a1
b = [b0]
a = [1, a1]
w = np.random.normal(0, 1, 1000)
w += 3
filter_b_a_freq_resp(b=b, a=a)

# %%
y = sig.lfilter(b, a, w)

plt.plot(y)

# %%
l = 100
b = np.full([l], 1/l)
#b = [1/10, 1/10, 1/10, 1/10, 1/10, 1/10, 1/10, 1/10, 1/10, 1/10]
a = [1]
y = sig.lfilter(b, a, w)
plt.plot(y)

# %%
filter_b_a_freq_resp(b, a)
# Out:
# C:\Users\npdho\AppData\Local\Temp\ipykernel_25288\2430638731.py:9: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(w, 20 * np.log10(abs(h)))
